# %%
import pandas as pd
import datetime as dt
import matplotlib.pyplot as plt

# %%
cf_tweets = pd.read_csv("Data/aggregate_results_24_07_2018_cleaned.csv")

# %%
cf_tweets.columns
# Out:
# Index(['Unnamed: 0', '_unit_id', '_golden', '_unit_state',
#        '_trusted_judgments', '_last_judgment_at', 'violence',
#        'violence_confidence', 'protest', 'protest_confidence', 'created_at',
#        'does_this_tweet_reportdiscuss_violent_incidents_happened_during_the_protest_gold',
#        'id', 'is_this_tweet_related_to_turkish_protests_2013_gold',
#        'proccd_text', 'text', 'clean_text'],
#       dtype='object')

# %%
cf_tweets = cf_tweets[['id', 'created_at', 'text', 'protest', 'violence']]

# %%
cf_tweets["created_at_dt"] = pd.to_datetime(cf_tweets["created_at"])

# %%
cf_tweets_dt = cf_tweets.set_index(cf_tweets["created_at_dt"])

# %%
cf_tweets_dt["created_at_dt"].describe()
# Out:
# count                    6498
# unique                   6493
# top       2013-06-01 20:24:42
# freq                        2
# first     2013-05-31 13:08:30
# last      2013-06-26 07:48:01
# Name: created_at_dt, dtype: object

# %%
len(cf_tweets_dt.resample("D"))
# Out:
# 27

# %%
len(cf_tweets_dt.resample("H"))
# Out:
# 619

# %%
plt.figure(figsize=(20,4))

plt.plot(cf_tweets_dt['violence'].resample("D", how='count'))
plt.show()
# Out:
# /home/fatma/anaconda2/envs/conda_python_env/lib/python3.4/site-packages/ipykernel_launcher.py:3: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...).count()
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
plt.figure(figsize=(20,4))

plt.plot(cf_tweets_dt[cf_tweets_dt['violence']==1].resample("D", how='count'))
plt.show()
# Out:
# /home/fatma/anaconda2/envs/conda_python_env/lib/python3.4/site-packages/ipykernel_launcher.py:3: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...).count()
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
plt.figure(figsize=(15,4))

plt.plot(cf_tweets_dt[cf_tweets_dt['violence']==1].resample("H", how='count'))
plt.show()
# Out:
# /home/fatma/anaconda2/envs/conda_python_env/lib/python3.4/site-packages/ipykernel_launcher.py:3: FutureWarning: how in .resample() is deprecated
# the new syntax is .resample(...).count()
#   This is separate from the ipykernel package so we can avoid doing imports until
